# %% [markdown]
# # Predicting Air Quality using AWS Forecast and OpenAQ dataset
#
# Outdoor particulate pollution was responsible for an estimated 4.2 million deaths worldwide in 2015, with a majority concentrated in east and south Asia. Millions more fell ill from breathing dirty air.
# This fine pollution mainly comes from burning things: Coal in power plants, gasoline in cars, chemicals in industrial processes, or woody materials and whatever else ignites during wildfires. The particles are too small for the eye to see — each about 35 times smaller than a grain of fine beach sand — but in high concentrations they cast a haze in the sky. And, when breathed in, they wreak havoc on human health(source- nytimes)
# The OpenAQ dataset is very rich and gives us a wealth of information on air quality across the globe.
# In this section we are trying to create an AWS Forecast to predict the air quality in a city. This would help us in many ways -
#
#
# - Parents can use the application to plan any outside activities with the kids. It might not be a good idea to go to a park if the air quality predictot/index is very bad that week.
# - The forecast can also be used by policymakers to come up with better ways to combat the air quality issues pro actively
# - The Air Quality Index information can also be used to regulate any traffic or wildfire activities in the area.

# %%
from pyathena import connect
import pandas as pd
import matplotlib.pyplot as plt

# %%
athena_data_bucket = "openaq-athena-bucket"
conn = connect(s3_staging_dir="s3://" + athena_data_bucket,
               region_name="us-east-1")

# %% [markdown]
# ### Create Athena database and import OpenAQ data into Athena, so that we can query it through sagemaker.

# %%
database = """
CREATE DATABASE IF NOT EXISTS db_openaq;
"""
cursor = conn.cursor()
cursor.execute(database)
print(cursor.fetchall())
# Out:
# []

# %%
table = """
CREATE EXTERNAL TABLE IF NOT EXISTS db_openaq.tbl_openaq2(
  `date` struct<utc:string,local:string> COMMENT 'from deserializer', 
  `parameter` string COMMENT 'from deserializer', 
  `location` string COMMENT 'from deserializer', 
  `value` float COMMENT 'from deserializer', 
  `unit` string COMMENT 'from deserializer', 
  `city` string COMMENT 'from deserializer', 
  `attribution` array<struct<name:string,url:string>> COMMENT 'from deserializer', 
  `averagingperiod` struct<unit:string,value:float> COMMENT 'from deserializer', 
  `coordinates` struct<latitude:float,longitude:float> COMMENT 'from deserializer', 
  `country` string COMMENT 'from deserializer', 
  `sourcename` string COMMENT 'from deserializer', 
  `sourcetype` string COMMENT 'from deserializer', 
  `mobile` string COMMENT 'from deserializer')
ROW FORMAT SERDE 
  'org.openx.data.jsonserde.JsonSerDe' 
STORED AS INPUTFORMAT 
  'org.apache.hadoop.mapred.TextInputFormat' 
OUTPUTFORMAT 
  'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
LOCATION
  's3://openaq-fetches/realtime-gzipped'
TBLPROPERTIES (
  'transient_lastDdlTime'='1518373755')
"""
cursor = conn.cursor()
cursor.execute(table)
print(cursor.fetchall())
# Out:
# []

# %%
table = """
CREATE EXTERNAL TABLE IF NOT EXISTS db_openaq.tbl_openaq2(
  `date` struct<utc:string,local:string> COMMENT 'from deserializer', 
  `parameter` string COMMENT 'from deserializer', 
  `location` string COMMENT 'from deserializer', 
  `value` float COMMENT 'from deserializer', 
  `unit` string COMMENT 'from deserializer', 
  `city` string COMMENT 'from deserializer', 
  `attribution` array<struct<name:string,url:string>> COMMENT 'from deserializer', 
  `averagingperiod` struct<unit:string,value:float> COMMENT 'from deserializer', 
  `coordinates` struct<latitude:float,longitude:float> COMMENT 'from deserializer', 
  `country` string COMMENT 'from deserializer', 
  `sourcename` string COMMENT 'from deserializer', 
  `sourcetype` string COMMENT 'from deserializer', 
  `mobile` string COMMENT 'from deserializer')
ROW FORMAT SERDE 
  'org.openx.data.jsonserde.JsonSerDe' 
STORED AS INPUTFORMAT 
  'org.apache.hadoop.mapred.TextInputFormat' 
OUTPUTFORMAT 
  'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
LOCATION
  's3://openaq-fetches/realtime-gzipped'
TBLPROPERTIES (
  'transient_lastDdlTime'='1518373755')
"""
cursor = conn.cursor()
cursor.execute(table)
print(cursor.fetchall())

# %%
df_pm25 = pd.read_sql("SELECT country,avg(value)  FROM db_openaq.tbl_openaq2 WHERE parameter = 'pm25' GROUP BY country;", conn)
df_pm25.columns = ['country','pm25']
df_pm25
# Out:
#    country        pm25
# 0       MT   20.957464
# 1       BR   14.967491
# 2       TJ   68.403656
# 3       HK   20.195745
# 4       BA   19.843891
# 5       HR   14.167453
# 6       BK   35.487500
# 7       IQ  -12.859020
# 8       XK   -0.948590
# 9       NG   16.333216
# 10      KV   28.871965
# 11      SG   70.592940
# 12      ET -514.796940
# 13      SA   32.182377
# 14      MX   20.390675
# 15      KZ  -27.034214
# 16      CR    5.808219
# 17      TW   20.637804
# 18      GH   79.530190
# 19      IZ   59.830883
# 20      TM  -29.336073
# 21      TX   21.604923
# 22      CZ   17.698969
# 23      GB   10.318537
# 24      VN  -74.003970
# 25      LK  -90.348350
# 26      LT    9.088533
# 27      FR    9.850260
# 28      CH   10.128955
# 29      MG   67.295350
# ..     ...         ...
# 53      BD  -24.588993
# 54      MM  -56.850925
# 55      CE   16.468647
# 56      AR   10.181169
# 57      FI    5.317239
# 58      PT    3.648575
# 59      BG   93.271520
# 60      UZ -132.876310
# 61      AF   88.360664
# 62      sk    8.270992
# 63      NL -202.524640
# 64      NP  -47.833930
# 65      PE  -14.954637
# 66      PL   20.459263
# 67      SK   16.439505
# 68      GT  -62.531300
# 69      UG  -84.145370
# 70      CW -409.465270
# 71      LA  -17.261963
# 72      BH  -40.861465
# 73      BM   29.220528
# 74      CS    7.547591
# 75      DZ -187.528520
# 76      TI   71.078190
# 77      AE -104.451690
# 78      JO  -95.606445
# 79      IN   63.231903
# 80      SE   -0.740572
# 81      HU   16.191810
# 82      CA    6.349560
#
# [83 rows x 2 columns]

# %%
df_pm25 = df_pm25.sort_values(by=['pm25'])
#df_pm25 = df_pm25['value'][df_pm25['value'] < 0]  = 0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-125-447164520752> in <module>()
# ----> 1 df_pm25 = df_pm25.sort_values(by=['pm25'])
#       2 #df_pm25 = df_pm25['value'][df_pm25['value'] < 0]  = 0
#
# AttributeError: 'int' object has no attribute 'sort_values'

# %%
### Lets plot the chart

# %%
import plotly.express as px
fig = px.bar(df_pm25, x='country', y='pm25')
fig.show()
# Out:
# <div>
#
#
#             <div id="0ade4e89-f353-4c5b-bf9b-cf8ef1b45ea1" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0ade4e89-f353-4c5b-bf9b-cf8ef1b45ea1")) {
#                     Plotly.newPlot(
#                         '0ade4e89-f353-4c5b-bf9b-cf8ef1b45ea1',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "country=%{x}<br>pm25=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["ET", "CW", "CO", "NL", "DZ", "UZ", "AE", "JO", "LK", "UG", "AU", "VN", "GT", "MM", "NP", "BH", "TM", "KZ", "BD", "LA", "ID", "PE", "IQ", "XK", "SE", "IT", "ES", "IE", "PT", "KG", "FI", "CR", "CA", "KE", "NO", "CS", "US", "sk", "LT", "LU", "FR", "CH", "AR", "GB", "KW", "DE", "BE", "IL", "HR", "BR", "HU", "NG", "SK", "CE", "PH", "CZ", "RS", "BA", "HK", "MX", "PL", "TW", "MT", "TX", "CL", "KV", "BM", "MK", "SA", "PK", "BK", "CN", "KU", "IZ", "IN", "MG", "TJ", "SG", "TI", "MN", "GH", "AF", "BG"], "xaxis": "x", "y": [-514.79694, -409.46527, -404.14645, -202.52464, -187.52852, -132.87631, -104.45169, -95.606445, -90.34835, -84.14537, -75.55274, -74.00397, -62.5313, -56.850925, -47.83393, -40.861465, -29.336073, -27.034214, -24.588993, -17.261963, -16.084871, -14.954637, -12.85902, -0.9485901, -0.74057156, 0.13667426, 2.5440295, 3.222846, 3.6485753, 4.525985, 5.317239, 5.808219, 6.3495603, 6.907178, 7.2633395, 7.547591, 7.710482, 8.270992, 9.088533, 9.278076, 9.85026, 10.128955, 10.181169, 10.318537, 10.941961, 11.284966, 11.648714, 13.814184, 14.167453, 14.967491, 16.19181, 16.333216, 16.439505, 16.468647, 17.232151, 17.698969, 19.639078, 19.843891, 20.195745, 20.390675, 20.459263, 20.637804, 20.957464, 21.604923, 22.944368, 28.871965, 29.220528, 31.527601, 32.182377, 34.253635, 35.4875, 36.605473, 44.211285, 59.830883, 63.231903, 67.29535, 68.403656, 70.59294, 71.07819, 74.8325, 79.53019, 88.360664, 93.27152], "yaxis": "y"}],
#                         {"barmode": "relative", "height": 600, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}],  ...

# %%
df_pm25_delhi = pd.read_sql("SELECT * FROM db_openaq.tbl_openaq2 WHERE parameter = 'pm25' AND city = 'Delhi';", conn)
#df_pm25_delhi.columns = ['country','pm25']
df_pm25_delhi
# Out:
#                                                      date parameter  \
# 0       {utc=2015-07-17T01:10:00.000Z, local=2015-07-1...      pm25
# 1       {utc=2015-07-17T00:30:00.000Z, local=2015-07-1...      pm25
# 2       {utc=2015-07-17T01:30:00.000Z, local=2015-07-1...      pm25
# 3       {utc=2015-07-17T02:30:00.000Z, local=2015-07-1...      pm25
# 4       {utc=2015-07-17T02:30:00.000Z, local=2015-07-1...      pm25
# 5       {utc=2015-07-17T02:10:00.000Z, local=2015-07-1...      pm25
# 6       {utc=2015-07-17T00:30:00.000Z, local=2015-07-1...      pm25
# 7       {utc=2015-07-17T04:10:00.000Z, local=2015-07-1...      pm25
# 8       {utc=2015-07-17T00:10:00.000Z, local=2015-07-1...      pm25
# 9       {utc=2015-07-17T00:30:00.000Z, local=2015-07-1...      pm25
# 10      {utc=2015-07-17T01:30:00.000Z, local=2015-07-1...      pm25
# 11      {utc=2015-07-17T04:30:00.000Z, local=2015-07-1...      pm25
# 12      {utc=2015-07-17T08:20:00.000Z, local=2015-07-1...      pm25
# 13      {utc=2015-07-17T08:10:00.000Z, local=2015-07-1...      pm25
# 14      {utc=2015-07-17T09:10:00.000Z, local=2015-07-1...      pm25
# 15      {utc=2015-07-17T07:30:00.000Z, local=2015-07-1...      pm25
# 16      {utc=2015-07-17T10:10:00.000Z, local=2015-07-1...      pm25
# 17      {utc=2015-07-17T07:30:00.000Z, local=2015-07-1...      pm25
# 18      {utc=2015-07-17T08:10:00.000Z, local=2015-07-1...      pm25
# 19      {utc=2015-07-17T08:30:00.000Z, local=2015-07-1...      pm25
# 20      {utc=2015-07-17T09:30:00.000Z, local=2015-07-1...      pm25
# 21      {utc=2015-07-17T08:10:00.000Z, local=2015-07-1...      pm25
# 22      {utc=2015-07-17T07:30:00.000Z, local=2015-07-1...      pm25
# 23      {utc=2015-07-17T10:30:00.000Z, local=2015-07-1...      pm25
# 24      {utc=2015-07-17T09:10:00.000Z, local=2015-07-1...      pm25
# 25      {utc=2015-07-17T10:10:00.000Z, local=2015-07-1...      pm25
# 26      {utc=2015-07-17T12:10:00.000Z, local=2015-07-1...      pm25
# 27      {utc=2015-07-17T13:30:00.000Z, local=2015-07-1...      pm25
# 28      {utc=2015-07-17T11:30:00.000Z, local=2015-07-1...      pm25
# 29      {utc=2015-07-17T13:30:00.000Z, local=2015-07-1...      pm25
# ...                                                   ...       ...
# 791521  {utc=2019-11-14T03:00:00.000Z, local=2019-11-1...      pm25
# 791522  {utc=2019-11-14T02:30:00.000Z, local=2019-11-1...      pm25
# 791523  {utc=2019-11-14T02:15:00.000Z, local=2019-11-1...      pm25
# 791524  {utc=2019-11-14T02:15:00.000Z, local=2019-11-1...      pm25
# 791525  {utc=2019-11-14T02:15:00.000Z, local=2019-11-1...      pm25
# 791526  {utc=2019-11-14T02:30:00.000Z, local=2019-11-1...      pm25
# 791527  {utc=2019-11-14T02:15:00.000Z, local=2019-11-1...      pm25
# 791528  {utc=2019-11-14T02:00:00.000Z, local=2019-11-1...      pm25
# 791529  {utc=2019-11-14T02:00:00.000Z, local=2019-11-1...      pm25
# 791530  {utc=2019-11-14T02:00:00.000Z, local=2019-11-1...      pm25
# 791531  {utc=2019-09-16T12:00:00.000Z, local=2019-09-1...      pm25
# 791532  {utc=2019-09-16T12:00:00.000Z, local=2019-09-1...      pm25
# 791533  {utc=2019-09-16T11:30:00.000Z, local=2019-09-1...      pm25
# 791534  {utc=2019-09-16T12:00:00.000Z, local=2019-09-1...      pm25
# 791535  {utc=2019-09-16T12:00:00.000Z, local=2019-09-1...      pm25
# 791536  {utc=2019-09-16T11:45:00.000Z, local=2019-09-1...      pm25
# 791537  {utc=2019-09-16T11:30:00.000Z, local=2019-09-1...      pm25
# 791538  {utc=2019-09-16T11:30:00.000Z, local=2019-09-1...      pm25
# 791539  {utc=2019-09-16T11:15:00.000Z, local=2019-09-1...      pm25
# 791540  {utc=2019-09-16T11:30:00.000Z, local=2019-09-1...      pm25
# 791541  {utc=2019-09-16T11:30:00.000Z, local=2019-09-1...      pm25
# 791542  {utc=2019-09-16T11:30:00.000Z, local=2019-09-1...      pm25
# 791543  {utc=2019-09-16T11:15:00.000Z, local=2019-09-1...      pm25
# 791544  {utc=2019-09-16T11:30:00.000Z, local=2019-09-1...      pm25
# 791545  {utc=2019-09-16T11:30:00.000Z, local=2019-09-1...      pm25
# 791546  {utc=2019-09-16T11:30:00.000Z, local=2019-09-1...      pm25
# 791547  {utc=2019-09-16T11:15:00.000Z, local=2019-09-1...      pm25
# 791548  {utc=2019-09-16T11:15:00.000Z, local=2019-09-1...      pm25
# 791549  {utc=2019-09-16T11:30:00.000Z, local=2019-09-1...      pm25
# 791550  {utc=2019-09-16T11:15:00.000Z, local=2019-09-1...      pm25
#
#                                                 location   value   unit  \
# 0                                            Mandir Marg   39.00  µg/m³
# 1                                           Punjabi Bagh   92.00  µg/m³
# 2                                            Mandir Marg   57.00  µg/m³
# 3                                            Mandir Marg   60.00  µg/m³
# 4                                            Anand Vihar   98.00  µg/m³
# 5                                            Anand Vihar   88.00  µg/m³
# 6                                            Anand Vihar  132.00  µg/m³
# 7                                            Anand Vihar  121.00  µg/m³
# 8                                           Punjabi Bagh   75.00  µg/m³
# 9                                            Mandir Marg   39.00  µg/m³
# 10                                          Punjabi Bagh  129.00  µg/m³
# 11                                          Punjabi Bagh  131.00  µg/m³
# 12                                           Mandir Marg  112.00  µg/m³
# 13                                           Anand Vihar   32.00  µg/m³
# 14                                              RK Puram   95.00  µg/m³
# 15                                          Punjabi Bagh  150.00  µg/m³
# 16                                           Anand Vihar   51.00  µg/m³
# 17                                           Anand Vihar   32.00  µg/m³
# 18                                           Mandir Marg  112.00  µg/m³
# 19                                           Anand Vihar   56.00  µg/m³
# 20                                           Anand Vihar   51.00  µg/m³
# 21                                          Punjabi Bagh  150.00  µg/m³
# 22                                           Mandir Marg  112.00  µg/m³
# 23                                           Anand Vihar   80.00  µg/m³
# 24                                          Punjabi Bagh   97.00  µg/m³
# 25                                          Punjabi Bagh   68.00  µg/m³
# 26                                           Mandir Marg   62.00  µg/m³
# 27                                           Anand Vihar  129.00  µg/m³
# 28                                          Punjabi Bagh  151.00  µg/m³
# 29                                           Mandir Marg   69.00  µg/m³
# ...                                                  ...     ...    ...
# 791521                     North Campus, DU, Delhi - IMD  393.76  µg/m³
# 791522                            Shadipur, Delhi - CPCB  238.12  µg/m³
# 791523                           R K Puram, Delhi - DPCC  436.00  µg/m³
# 791524                         Mandir Marg, Delhi - DPCC  401.00  µg/m³
# 791525                        Punjabi Bagh, Delhi - DPCC  415.00  µg/m³
# 791526                            Sirifort, Delhi - CPCB  460.00  µg/m³
# 791527                              Bawana, Delhi - DPCC  476.00  µg/m³
# 791528                  Sri Aurobindo Marg, Delhi - DPCC  368.00  µg/m³
# 791529                              Mundka, Delhi - DPCC  547.00  µg/m³
# 791530                              Alipur, Delhi - DPCC  394.00  µg/m³
# 791531                            Aya Nagar, Delhi - IMD   73.80  µg/m³
# 791532                                 Pusa, Delhi - IMD   43.63  µg/m³
# 791533                                 DTU, Delhi - CPCB   59.16  µg/m³
# 791534                    CRRI Mathura Road, Delhi - IMD   17.11  µg/m³
# 791535                      Burari Crossing, Delhi - IMD    0.00  µg/m³
# 791536                     North Campus, DU, Delhi - IMD   52.88  µg/m³
# 791537                            Shadipur, Delhi - CPCB   12.39  µg/m³
# 791538                    Dwarka-Sector 8, Delhi - DPCC    58.00  µg/m³
# 791539                         Ashok Vihar, Delhi - DPCC   53.00  µg/m³
# 791540                        Jahangirpuri, Delhi - DPCC   59.00  µg/m³
# 791541            Jawaharlal Nehru Stadium, Delhi - DPCC   47.00  µg/m³
# 791542  Major Dhyan Chand National Stadium, Delhi - DPCC   48.00  µg/m³
# 791543                              Narela, Delhi - DPCC   44.00  µg/m³
# 791544                              Rohini, Delhi - DPCC   51.00  µg/m³
# 791545                          Patparganj, Delhi - DPCC   47.00  µg/m³
# 791546                         Sonia Vihar, Delhi - DPCC   40.00  µg/m³
# 791547                         Vivek Vihar, Delhi - DPCC   56.00  µg/m³
# 791548                            Wazirpur, Delhi - DPCC   52.00  µg/m³
# 791549                              Bawana, Delhi - DPCC   63.00  µg/m³
# 791550                              Mundka, Delhi - DPCC   57.00  µg/m³
#
#          city                                        attribution  \
# 0       Delhi                                               None
# 1       Delhi                                               None
# 2       Delhi                                               None
# 3       Delhi                                               None
# 4       Delhi                                               None
# 5       Delhi                                               None
# 6       Delhi                                               None
# 7       Delhi                                               None
# 8       Delhi                                               None
# 9       Delhi                                               None
# 10      Delhi                                               None
# 11      Delhi                                               None
# 12      Delhi                                               None
# 13      Delhi                                               None
# 14      Delhi                                               None
# 15      Delhi                                               None
# 16      Delhi                                               None
# 17      Delhi                                               None
# 18      Delhi                                               None
# 19      Delhi                                               None
# 20      Delhi                                               None
# 21      Delhi                                               None
# 22      Delhi                                               None
# 23      Delhi                                               None
# 24      Delhi                                               None
# 25      Delhi                                               None
# 26      Delhi                                               None
# 27      Delhi                                               None
# 28      Delhi                                               None
# 29      Delhi                                               None
# ...       ...                                                ...
# 791521  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791522  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791523  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791524  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791525  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791526  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791527  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791528  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791529  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791530  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791531  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791532  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791533  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791534  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791535  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791536  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791537  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791538  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791539  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791540  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791541  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791542  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791543  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791544  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791545  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791546  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791547  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791548  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791549  Delhi  [{name=Central Pollution Control Board, url=ht...
# 791550  Delhi  [{name=Central Pollution Control Board, url=ht...
#
#                  averagingperiod                                coordinates  \
# 0                           None      {latitude=28.6341, longitude=77.2005}
# 1                           None      {latitude=28.6683, longitude=77.1167}
# 2                           None      {latitude=28.6341, longitude=77.2005}
# 3                           None      {latitude=28.6341, longitude=77.2005}
# 4                           None      {latitude=28.6508, longitude=77.3152}
# 5                           None      {latitude=28.6508, longitude=77.3152}
# 6                           None      {latitude=28.6508, longitude=77.3152}
# 7                           None      {latitude=28.6508, longitude=77.3152}
# 8                           None      {latitude=28.6683, longitude=77.1167}
# 9                           None      {latitude=28.6341, longitude=77.2005}
# 10                          None      {latitude=28.6683, longitude=77.1167}
# 11                          None      {latitude=28.6683, longitude=77.1167}
# 12                          None      {latitude=28.6341, longitude=77.2005}
# 13                          None      {latitude=28.6508, longitude=77.3152}
# 14                          None      {latitude=28.5648, longitude=77.1744}
# 15                          None      {latitude=28.6683, longitude=77.1167}
# 16                          None      {latitude=28.6508, longitude=77.3152}
# 17                          None      {latitude=28.6508, longitude=77.3152}
# 18                          None      {latitude=28.6341, longitude=77.2005}
# 19                          None      {latitude=28.6508, longitude=77.3152}
# 20                          None      {latitude=28.6508, longitude=77.3152}
# 21                          None      {latitude=28.6683, longitude=77.1167}
# 22                          None      {latitude=28.6341, longitude=77.2005}
# 23                          None      {latitude=28.6508, longitude=77.3152}
# 24                          None      {latitude=28.6683, longitude=77.1167}
# 25                          None      {latitude=28.6683, longitude=77.1167}
# 26                          None      {latitude=28.6341, longitude=77.2005}
# 27                          None      {latitude=28.6508, longitude=77.3152}
# 28                          None      {latitude=28.6683, longitude=77.1167}
# 29                          None      {latitude=28.6341, longitude=77.2005}
# ...                          ...                                        ...
# 791521  {unit=hours, value=0.25}   {latitude=28.657381, longitude=77.15855}
# 791522  {unit=hours, value=0.25}   {latitude=28.651478, longitude=77.14731}
# 791523  {unit=hours, value=0.25}  {latitude=28.563263, longitude=77.186935}
# 791524  {unit=hours, value=0.25}  {latitude=28.636429, longitude=77.201065}
# 791525  {unit=hours, value=0.25}   {latitude=28.674046, longitude=77.13102}
# 791526  {unit=hours, value=0.25}  {latitude=28.550425, longitude=77.215935}
# 791527  {unit=hours, value=0.25}     {latitude=28.7762, longitude=77.05107}
# 791528  {unit=hours, value=0.25}  {latitude=28.531345, longitude=77.190155}
# 791529  {unit=hours, value=0.25}   {latitude=28.684677, longitude=77.07658}
# 791530  {unit=hours, value=0.25}   {latitude=28.815329, longitude=77.15301}
# 791531  {unit=hours, value=0.25}   {latitude=28.470692, longitude=77.10994}
# 791532  {unit=hours, value=0.25}   {latitude=28.639645, longitude=77.14626}
# 791533  {unit=hours, value=0.25}    {latitude=28.75005, longitude=77.11126}
# 791534  {unit=hours, value=0.25}    {latitude=28.5512, longitude=77.273575}
# 791535  {unit=hours, value=0.25}    {latitude=28.72565, longitude=77.20116}
# 791536  {unit=hours, value=0.25}   {latitude=28.657381, longitude=77.15855}
# 791537  {unit=hours, value=0.25}   {latitude=28.651478, longitude=77.14731}
# 791538  {unit=hours, value=0.25}    {latitude=28.571028, longitude=77.0719}
# 791539  {unit=hours, value=0.25}   {latitude=28.695381, longitude=77.18166}
# 791540  {unit=hours, value=0.25}    {latitude=28.73282, longitude=77.17063}
# 791541  {unit=hours, value=0.25}   {latitude=28.58028, longitude=77.233826}
# 791542  {unit=hours, value=0.25}    {latitude=28.61128, longitude=77.23774}
# 791543  {unit=hours, value=0.25}   {latitude=28.822836, longitude=77.10198}
# 791544  {unit=hours, value=0.25}   {latitude=28.732529, longitude=77.11992}
# 791545  {unit=hours, value=0.25}   {latitude=28.623749, longitude=77.28721}
# 791546  {unit=hours, value=0.25}   {latitude=28.710508, longitude=77.24948}
# 791547  {unit=hours, value=0.25}   {latitude=28.672342, longitude=77.31526}
# 791548  {unit=hours, value=0.25}   {latitude=28.699793, longitude=77.16545}
# 791549  {unit=hours, value=0.25}     {latitude=28.7762, longitude=77.05107}
# 791550  {unit=hours, value=0.25}   {latitude=28.684677, longitude=77.07658}
#
#        country    sourcename  sourcetype mobile
# 0           IN   Mandir Marg        None   None
# 1           IN  Punjabi Bagh        None   None
# 2           IN   Mandir Marg        None   None
# 3           IN   Mandir Marg        None   None
# 4           IN   Anand Vihar        None   None
# 5           IN   Anand Vihar        None   None
# 6           IN   Anand Vihar        None   None
# 7           IN   Anand Vihar        None   None
# 8           IN  Punjabi Bagh        None   None
# 9           IN   Mandir Marg        None   None
# 10          IN  Punjabi Bagh        None   None
# 11          IN  Punjabi Bagh        None   None
# 12          IN   Mandir Marg        None   None
# 13          IN   Anand Vihar        None   None
# 14          IN      RK Puram        None   None
# 15          IN  Punjabi Bagh        None   None
# 16          IN   Anand Vihar        None   None
# 17          IN   Anand Vihar        None   None
# 18          IN   Mandir Marg        None   None
# 19          IN   Anand Vihar        None   None
# 20          IN   Anand Vihar        None   None
# 21          IN  Punjabi Bagh        None   None
# 22          IN   Mandir Marg        None   None
# 23          IN   Anand Vihar        None   None
# 24          IN  Punjabi Bagh        None   None
# 25          IN  Punjabi Bagh        None   None
# 26          IN   Mandir Marg        None   None
# 27          IN   Anand Vihar        None   None
# 28          IN  Punjabi Bagh        None   None
# 29          IN   Mandir Marg        None   None
# ...        ...           ...         ...    ...
# 791521      IN         caaqm  government  false
# 791522      IN         caaqm  government  false
# 791523      IN         caaqm  government  false
# 791524      IN         caaqm  government  false
# 791525      IN         caaqm  government  false
# 791526      IN         caaqm  government  false
# 791527      IN         caaqm  government  false
# 791528      IN         caaqm  government  false
# 791529      IN         caaqm  government  false
# 791530      IN         caaqm  government  false
# 791531      IN         caaqm  government  false
# 791532      IN         caaqm  government  false
# 791533      IN         caaqm  government  false
# 791534      IN         caaqm  government  false
# 791535      IN         caaqm  government  false
# 791536      IN         caaqm  government  false
# 791537      IN         caaqm  government  false
# 791538      IN         caaqm  government  false
# 791539      IN         caaqm  government  false
# 791540      IN         caaqm  government  false
# 791541      IN         caaqm  government  false
# 791542      IN         caaqm  government  false
# 791543      IN         caaqm  government  false
# 791544      IN         caaqm  government  false
# 791545      IN         caaqm  government  false
# 791546      IN         caaqm  government  false
# 791547      IN         caaqm  government  false
# 791548      IN         caaqm  government  false
# 791549      IN         caaqm  government  false
# 791550      IN         caaqm  government  false
#
# [791551 rows x 13 columns]

# %%
df_pm25_delhi['datetime']= df_pm25_delhi['date'].str[5:15]

# %%
df_pm25_delhi['time1'] = pd.to_datetime(df_pm25_delhi['datetime'], format='%Y-%m-%d')

# %%
df_delhi = df_pm25_delhi.groupby(['city', 'parameter','time1']).mean().reset_index(drop=False)

# %%
df_delhi['value'].mean()
# Out:
# 93.39339321529081

# %%
df_delhi['value'][df_delhi.value < 0] = df_delhi['value'].mean()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(x=df_delhi.time1, y=df_delhi.value, name="microgram/m3",
                         line_color='deepskyblue'))

fig.update_layout(title_text='Delhi - PPM - Time Series with Rangeslider',
                  xaxis_rangeslider_visible=True)
fig.show()
# Out:
# <div>
#
#
#             <div id="c23b6610-7100-4bc0-a91f-8d4a3bc20863" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c23b6610-7100-4bc0-a91f-8d4a3bc20863")) {
#                     Plotly.newPlot(
#                         'c23b6610-7100-4bc0-a91f-8d4a3bc20863',
#                         [{"line": {"color": "deepskyblue"}, "name": "microgram/m3", "type": "scatter", "x": ["2015-06-29T00:00:00", "2015-06-30T00:00:00", "2015-07-01T00:00:00", "2015-07-02T00:00:00", "2015-07-03T00:00:00", "2015-07-04T00:00:00", "2015-07-06T00:00:00", "2015-07-07T00:00:00", "2015-07-08T00:00:00", "2015-07-09T00:00:00", "2015-07-10T00:00:00", "2015-07-11T00:00:00", "2015-07-12T00:00:00", "2015-07-13T00:00:00", "2015-07-14T00:00:00", "2015-07-15T00:00:00", "2015-07-16T00:00:00", "2015-07-17T00:00:00", "2015-07-18T00:00:00", "2015-07-20T00:00:00", "2015-07-21T00:00:00", "2015-07-22T00:00:00", "2015-07-23T00:00:00", "2015-07-24T00:00:00", "2015-08-02T00:00:00", "2015-08-03T00:00:00", "2015-08-04T00:00:00", "2015-08-05T00:00:00", "2015-08-06T00:00:00", "2015-08-07T00:00:00", "2015-08-08T00:00:00", "2015-08-09T00:00:00", "2015-08-10T00:00:00", "2015-08-11T00:00:00", "2015-08-12T00:00:00", "2015-08-13T00:00:00", "2015-08-14T00:00:00", "2015-08-15T00:00:00", "2015-08-16T00:00:00", "2015-08-17T00:00:00", "2015-08-18T00:00:00", "2015-08-19T00:00:00", "2015-08-20T00:00:00", "2015-08-21T00:00:00", "2015-08-22T00:00:00", "2015-08-23T00:00:00", "2015-08-24T00:00:00", "2015-08-25T00:00:00", "2015-08-26T00:00:00", "2015-08-27T00:00:00", "2015-08-28T00:00:00", "2015-08-31T00:00:00", "2015-09-01T00:00:00", "2015-09-02T00:00:00", "2015-09-03T00:00:00", "2015-09-04T00:00:00", "2015-09-05T00:00:00", "2015-09-07T00:00:00", "2015-09-08T00:00:00", "2015-09-09T00:00:00", "2015-09-10T00:00:00", "2015-09-11T00:00:00", "2015-09-14T00:00:00", "2015-09-15T00:00:00", "2015-09-16T00:00:00", "2015-09-17T00:00:00", "2015-09-18T00:00:00", "2015-09-19T00:00:00", "2015-09-20T00:00:00", "2015-09-21T00:00:00", "2015-09-22T00:00:00", "2015-09-23T00:00:00", "2015-09-24T00:00:00", "2015-09-25T00:00:00", "2015-09-26T00:00:00", "2015-09-28T00:00:00", "2015-09-29T00:00:00", "2015-09-30T00:00:00", "2015-10-01T00:00:00", "2015-10-02T00:00:00", "2015-10-03T00:00:00", "2015-10-04T00:00:00", "2015-10-06T00:00:00", "2015-10-07T00:00:00", "2015-10-09T00:00:00", "2015-10-14T00:00:00", "2015-10-15T00:00:00", "2015-10-16T00:00:00", "2015-10-19T00:00:00", "2015-10-20T00:00:00", "2015-10-21T00:00:00", "2015-10-23T00:00:00", "2015-10-24T00:00:00", "2015-10-25T00:00:00", "2015-10-26T00:00:00", "2015-10-27T00:00:00", "2015-10-28T00:00:00", "2015-10-29T00:00:00", "2015-10-30T00:00:00", "2015-10-31T00:00:00", "2015-11-01T00:00:00", "2015-11-02T00:00:00", "2015-11-03T00:00:00", "2015-11-04T00:00:00", "2015-11-05T00:00:00", "2015-11-06T00:00:00", "2015-11-07T00:00:00", "2015-11-08T00:00:00", "2015-11-09T00:00:00", "2015-11-10T00:00:00", "2015-11-11T00:00:00", "2015-11-12T00:00:00", "2015-11-13T00:00:00", "2015-11-14T00:00:00", "2015-11-15T00:00:00", "2015-11-16T00:00:00", "2015-11-20T00:00:00", "2015-11-21T00:00:00", "2015-11-22T00:00:00", "2015-11-23T00:00:00", "2015-11-24T00:00:00", "2015-11-25T00:00:00", "2015-11-26T00:00:00", "2015-11-27T00:00:00", "2015-11-28T00:00:00", "2015-11-29T00:00:00", "2015-11-30T00:00:00", "2015-12-01T00:00:00", "2015-12-02T00:00:00", "2015-12-03T00:00:00", "2015-12-04T00:00:00", "2015-12-05T00:00:00", "2015-12-06T00:00:00", "2015-12-07T00:00:00", "2015-12-08T00:00:00", "2015-12-09T00:00:00", "2015-12-10T00:00:00", "2015-12-11T00:00:00", "2015-12-12T00:00:00", "2015-12-13T00:00:00", "2015-12-14T00:00:00", "2015-12-15T00:00:00", "2015-12-16T00:00:00", "2015-12-17T00:00:00", "2015-12-18T00:00:00", "2015-12-19T00:00:00", "2015-12-20T00:00:00", "2015-12-21T00:00:00", "2015-12-22T00:00:00", "2015-12-23T00:00:00", "2015-12-24T00:00:00", "2015-12-25T00:00:00", "2015-12-26T00:00:00", "2015-12-27T00:00:00", "2015-12-28T00:00:00", "2015-12-29T00:00:00", "2016-01-03T00:00:00", "2016-01-04T00:00:00", "2016-01-05T00:00:00", "2016-01-06T00:00:00", "2016-01-07T00:00:00", "2016-01-08T00:00:00", "2016-01-09T00:00:00", "2016-01-10T00:00:00", "2016-01-11T00:00:00", "2016-01-12T00:00:00", "2016-01-13T00:00:00", "2016-01-14T00:00:00", "2016-01-15T00:00:00", "201 ...

# %% [markdown]
# ### As you can see the PPM concentration in Delhi during winters in almost 1500 which is the most toxic level manageable by humans

# %%
df_pred = df_delhi[['city','time1','value']]

# %%
df_pred.columns = ['item','timestamp','demand']

# %% [markdown]
# ## Now we would use Amazon Forecast to predict the Air Quality in Delhi in the next 2 weeks

# %% [markdown]
# ## AWS Forecast to predict the forecast of the ppm in Delhi

# %%
import boto3
from time import sleep
import subprocess
import pandas as pd
import json
import time

# %%
forecast = boto3.client(service_name='forecast') 
forecastquery = boto3.client(service_name='forecastquery')

# %%
DATASET_FREQUENCY = "M" 
TIMESTAMP_FORMAT = "yyyy-MM-dd"
key="airquality/airquality_delhi.csv"
bucket_name = "openaq-forecast"

# %%
project = 'air_quality_forecast'
datasetName= project+'_ds'
datasetGroupName= project +'_dsg'
s3DataPath = "s3://"+bucket_name+"/"+key

# %%
# Now save things 
# %store project

# %%
create_dataset_group_response = forecast.create_dataset_group(DatasetGroupName=datasetGroupName,
                                                              Domain="CUSTOM",
                                                             )
datasetGroupArn = create_dataset_group_response['DatasetGroupArn']

# %%
forecast.describe_dataset_group(DatasetGroupArn=datasetGroupArn)

# %%
# Specify the schema of your dataset here. Make sure the order of columns matches the raw data files.
schema ={
   "Attributes":[
      {
         "AttributeName":"city",
         "AttributeType":"string"
      },
      {
         "AttributeName":"timestamp",
         "AttributeType":"timestamp"
      },
      {
         "AttributeName":"pm25",
         "AttributeType":"float"
      }

   ]
}

# %%
response=forecast.create_dataset(
                    Domain="CUSTOM",
                    DatasetType='TARGET_TIME_SERIES',
                    DatasetName=datasetName,
                    DataFrequency=DATASET_FREQUENCY, 
                    Schema = schema
)

# %%
datasetArn = response['DatasetArn']
forecast.describe_dataset(DatasetArn=datasetArn)

# %%
forecast.update_dataset_group(DatasetGroupArn=datasetGroupArn, DatasetArns=[datasetArn])

# %%
role_arn = "arn:aws:iam::611181293678:role/AmazonForecast-ExecutionRole-abhi"

# %%
datasetImportJobName = 'SP_DSIMPORT_JOB_TARGET'
ds_import_job_response=forecast.create_dataset_import_job(DatasetImportJobName=datasetImportJobName,
                                                          DatasetArn=datasetArn,
                                                          DataSource= {
                                                              "S3Config" : {
                                                                 "Path":s3DataPath,
                                                                 "RoleArn": role_arn
                                                              } 
                                                          },
                                                          TimestampFormat=TIMESTAMP_FORMAT
                                                         )

# %%
ds_import_job_arn=ds_import_job_response['DatasetImportJobArn']
print(ds_import_job_arn)

# %%
while True:
    dataImportStatus = forecast.describe_dataset_import_job(DatasetImportJobArn=ds_import_job_arn)['Status']
    print(dataImportStatus)
    if dataImportStatus != 'ACTIVE' and dataImportStatus != 'CREATE_FAILED':
        sleep(30)
    else:
        break

# %%
forecast.describe_dataset_import_job(DatasetImportJobArn=ds_import_job_arn)

# %%
# %store datasetGroupArn
# %store datasetArn
# %store role_arn
# %store key
# %store bucket_name

# %% [markdown]
# # Forecast Predictor

# %%
import boto3
from time import sleep
import subprocess
import pandas as pd
import json
import time

# %%
# %store -r

# %%
forecast = boto3.client(service_name='forecast') 
forecastquery = boto3.client(service_name='forecastquery')

# %%
predictorName= project+'_prophet'

# %%
forecastHorizon = 14

# %%
algorithm = 'Prophet'
algorithm_arn = 'arn:aws:forecast:::algorithm/'
algorithm_arn_prophet = algorithm_arn + algorithm

# %%
create_predictor_response=forecast.create_predictor(PredictorName=predictorName, 
                                                  AlgorithmArn=algorithm_arn_prophet,
                                                  ForecastHorizon=forecastHorizon,
                                                  PerformAutoML= False,
                                                  PerformHPO=False,
                                                  EvaluationParameters= {"NumberOfBacktestWindows": 1, 
                                                                         "BackTestWindowOffset": 12}, 
                                                  InputDataConfig= {"DatasetGroupArn": datasetGroupArn},
                                                  FeaturizationConfig= {"ForecastFrequency": "M", 
                                                                        "Featurizations": 
                                                                        [
                                                                          {"AttributeName": "target_value", 
                                                                           "FeaturizationPipeline": 
                                                                            [
                                                                              {"FeaturizationMethodName": "filling", 
                                                                               "FeaturizationMethodParameters": 
                                                                                {"frontfill": "none", 
                                                                                 "middlefill": "zero", 
                                                                                 "backfill": "zero"}
                                                                              }
                                                                            ]
                                                                          }
                                                                        ]
                                                                       }
                                                 )

# %%
predictor_arn_prophet = create_predictor_response['PredictorArn']

# %%
while True:
    predictorStatus = forecast.describe_predictor(PredictorArn=predictor_arn_prophet)['Status']
    print(predictorStatus)
    if predictorStatus != 'ACTIVE' and predictorStatus != 'CREATE_FAILED':
        sleep(30)
    else:
        break

# %%
forecast.get_accuracy_metrics(PredictorArn=predictor_arn_prophet)

# %%
forecastName= project+'_prophet_forecast'

# %%
create_forecast_response=forecast.create_forecast(ForecastName=forecastName,
                                                  PredictorArn=predictor_arn_prophet)
forecast_arn_prophet = create_forecast_response['ForecastArn']

# %%
while True:
    forecastStatus = forecast.describe_forecast(ForecastArn=forecast_arn_prophet)['Status']
    print(forecastStatus)
    if forecastStatus != 'ACTIVE' and forecastStatus != 'CREATE_FAILED':
        sleep(30)
    else:
        break

# %%
print(forecast_arn_prophet)
print()
forecastResponse = forecastquery.query_forecast(
    ForecastArn=forecast_arn_prophet,
    Filters={"item_id":"CYCL000036443"}
)
print(forecastResponse)
